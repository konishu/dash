# %%
from assets import models
import pandas as pd

from assets.database import db_session

# %%
df = pd.read_csv('assets/data.csv')

# %%
df['date'][0]
# Out:
# '2019/1/17'

# %%
import datetime

# %%
df.iloc[0,0]
# Out:
# '2019/1/17'

# %%
date = datetime.datetime.strptime(df.iloc[0,0],'%Y/%m/%d').date()
date
# Out:
# datetime.date(2019, 1, 17)

# %%
for index,_df in df.iterrows():
    date = datetime.datetime.strptime(_df['date'],'%Y/%m/%d').date()
    row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
    db_session.add(row)
db_session.commit()
# Out:
# 2020-03-11 16:49:46,218 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-03-11 16:49:46,218 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-11 16:49:46,219 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-03-11 16:49:46,220 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-11 16:49:46,221 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-11 16:49:46,229 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,229 INFO sqlalchemy.engine.base.Engine ('2019-01-17', 2671, 194, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,231 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,232 INFO sqlalchemy.engine.base.Engine ('2019-01-18', 2671, 195, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,232 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,233 INFO sqlalchemy.engine.base.Engine ('2019-01-19', 2674, 197, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,234 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,235 INFO sqlalchemy.engine.base.Engine ('2019-01-20', 2685, 199, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,236 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,237 INFO sqlalchemy.engine.base.Engine ('2019-01-21', 2695, 199, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,238 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,239 INFO sqlalchemy.engine.base.Engine ('2019-01-22', 2701, 200, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,240 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,241 INFO sqlalchemy.engine.base.Engine ('2019-01-23', 2710, 200, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,242 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,243 INFO sqlalchemy.engine.base.Engine ('2019-01-24', 2718, 201, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,243 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,244 INFO sqlalchemy.engine.base.Engine ('2019-01-25', 2722, 201, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,246 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,246 INFO sqlalchemy.engine.base.Engine ('2019-01-26', 2725, 201, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,247 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,248 INFO sqlalchemy.engine.base.Engine ('2019-01-27', 2734, 202, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,249 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,250 INFO sqlalchemy.engine.base.Engine ('2019-01-28', 2753, 204, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,251 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,252 INFO sqlalchemy.engine.base.Engine ('2019-01-29', 2773, 206, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,253 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,254 INFO sqlalchemy.engine.base.Engine ('2019-01-30', 2785, 208, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,255 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,256 INFO sqlalchemy.engine.base.Engine ('2019-01-31', 2803, 210, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,256 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,258 INFO sqlalchemy.engine.base.Engine ('2019-02-01', 2845, 211, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,259 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,260 INFO sqlalchemy.engine.base.Engine ('2019-02-02', 2847, 213, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,261 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,262 INFO sqlalchemy.engine.base.Engine ('2019-02-03', 2847, 213, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,263 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,264 INFO sqlalchemy.engine.base.Engine ('2019-02-04', 2851, 217, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,265 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,266 INFO sqlalchemy.engine.base.Engine ('2019-02-05', 2852, 218, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,267 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,268 INFO sqlalchemy.engine.base.Engine ('2019-02-06', 2857, 219, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,269 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,271 INFO sqlalchemy.engine.base.Engine ('2019-02-07', 2861, 220, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,272 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,273 INFO sqlalchemy.engine.base.Engine ('2019-02-08', 2865, 222, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,274 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,275 INFO sqlalchemy.engine.base.Engine ('2019-02-09', 2870, 224, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,276 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,278 INFO sqlalchemy.engine.base.Engine ('2019-02-10', 2875, 224, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,280 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,281 INFO sqlalchemy.engine.base.Engine ('2019-02-11', 2892, 227, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,282 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,283 INFO sqlalchemy.engine.base.Engine ('2019-02-12', 2906, 229, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,284 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,285 INFO sqlalchemy.engine.base.Engine ('2019-02-13', 2919, 229, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,286 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,287 INFO sqlalchemy.engine.base.Engine ('2019-02-14', 2942, 231, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,288 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,289 INFO sqlalchemy.engine.base.Engine ('2019-02-15', 2974, 232, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,290 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,291 INFO sqlalchemy.engine.base.Engine ('2019-02-16', 2977, 234, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,292 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,293 INFO sqlalchemy.engine.base.Engine ('2019-02-17', 2978, 234, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,294 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,295 INFO sqlalchemy.engine.base.Engine ('2019-02-18', 2981, 234, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,296 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,298 INFO sqlalchemy.engine.base.Engine ('2019-02-19', 2983, 234, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,299 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,300 INFO sqlalchemy.engine.base.Engine ('2019-02-20', 2984, 237, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,301 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,302 INFO sqlalchemy.engine.base.Engine ('2019-02-21', 2987, 239, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,303 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,304 INFO sqlalchemy.engine.base.Engine ('2019-02-22', 2989, 239, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,306 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,306 INFO sqlalchemy.engine.base.Engine ('2019-02-23', 2993, 241, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,308 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,310 INFO sqlalchemy.engine.base.Engine ('2019-02-24', 2995, 241, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,312 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,313 INFO sqlalchemy.engine.base.Engine ('2019-02-25', 3009, 241, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,314 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,315 INFO sqlalchemy.engine.base.Engine ('2019-02-26', 3014, 243, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,316 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,317 INFO sqlalchemy.engine.base.Engine ('2019-02-27', 3023, 243, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,318 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,319 INFO sqlalchemy.engine.base.Engine ('2019-02-28', 3031, 243, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,320 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,321 INFO sqlalchemy.engine.base.Engine ('2019-03-01', 3052, 244, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,323 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,326 INFO sqlalchemy.engine.base.Engine ('2019-03-02', 3060, 245, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,327 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,328 INFO sqlalchemy.engine.base.Engine ('2019-03-03', 3062, 246, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,329 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,331 INFO sqlalchemy.engine.base.Engine ('2019-03-04', 3063, 249, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,333 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,334 INFO sqlalchemy.engine.base.Engine ('2019-03-05', 3066, 252, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,336 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,338 INFO sqlalchemy.engine.base.Engine ('2019-03-06', 3071, 254, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,342 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,343 INFO sqlalchemy.engine.base.Engine ('2019-03-07', 3074, 255, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,344 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,346 INFO sqlalchemy.engine.base.Engine ('2019-03-08', 3076, 256, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,347 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,348 INFO sqlalchemy.engine.base.Engine ('2019-03-09', 3077, 258, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,350 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,352 INFO sqlalchemy.engine.base.Engine ('2019-03-10', 3080, 258, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,355 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,355 INFO sqlalchemy.engine.base.Engine ('2019-03-11', 3087, 261, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,357 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,358 INFO sqlalchemy.engine.base.Engine ('2019-03-12', 3089, 261, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,360 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,361 INFO sqlalchemy.engine.base.Engine ('2019-03-13', 3093, 262, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,362 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,362 INFO sqlalchemy.engine.base.Engine ('2019-03-14', 3098, 262, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,363 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,364 INFO sqlalchemy.engine.base.Engine ('2019-03-15', 3104, 262, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,364 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,365 INFO sqlalchemy.engine.base.Engine ('2019-03-16', 3112, 262, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,367 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,367 INFO sqlalchemy.engine.base.Engine ('2019-03-17', 3120, 262, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,369 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,370 INFO sqlalchemy.engine.base.Engine ('2019-03-18', 3131, 265, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,371 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,371 INFO sqlalchemy.engine.base.Engine ('2019-03-19', 3142, 266, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,372 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,373 INFO sqlalchemy.engine.base.Engine ('2019-03-20', 3162, 266, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,374 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,374 INFO sqlalchemy.engine.base.Engine ('2019-03-21', 3173, 268, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,375 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,376 INFO sqlalchemy.engine.base.Engine ('2019-03-22', 3180, 269, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,377 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,378 INFO sqlalchemy.engine.base.Engine ('2019-03-23', 3187, 271, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,379 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,380 INFO sqlalchemy.engine.base.Engine ('2019-03-24', 3189, 271, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,381 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,382 INFO sqlalchemy.engine.base.Engine ('2019-03-25', 3196, 274, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,383 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,383 INFO sqlalchemy.engine.base.Engine ('2019-03-26', 3212, 274, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,385 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,411 INFO sqlalchemy.engine.base.Engine ('2019-03-27', 3220, 274, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,414 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,415 INFO sqlalchemy.engine.base.Engine ('2019-03-28', 3226, 275, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,417 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,418 INFO sqlalchemy.engine.base.Engine ('2019-03-29', 3241, 275, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,419 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,420 INFO sqlalchemy.engine.base.Engine ('2019-03-30', 3253, 278, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,422 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,425 INFO sqlalchemy.engine.base.Engine ('2019-03-31', 3255, 278, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,427 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,430 INFO sqlalchemy.engine.base.Engine ('2019-04-01', 3258, 280, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,436 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,438 INFO sqlalchemy.engine.base.Engine ('2019-04-02', 3262, 282, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,439 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,440 INFO sqlalchemy.engine.base.Engine ('2019-04-03', 3264, 282, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,441 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,442 INFO sqlalchemy.engine.base.Engine ('2019-04-04', 3272, 282, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,443 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,444 INFO sqlalchemy.engine.base.Engine ('2019-04-05', 3275, 284, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,445 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,446 INFO sqlalchemy.engine.base.Engine ('2019-04-06', 3276, 287, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,448 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,449 INFO sqlalchemy.engine.base.Engine ('2019-04-07', 3279, 289, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,450 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,451 INFO sqlalchemy.engine.base.Engine ('2019-04-08', 3285, 289, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,453 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,454 INFO sqlalchemy.engine.base.Engine ('2019-04-09', 3300, 291, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,455 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,457 INFO sqlalchemy.engine.base.Engine ('2019-04-10', 3306, 293, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,458 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,461 INFO sqlalchemy.engine.base.Engine ('2019-04-11', 3312, 295, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,462 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,464 INFO sqlalchemy.engine.base.Engine ('2019-04-12', 3319, 295, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,465 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,466 INFO sqlalchemy.engine.base.Engine ('2019-04-13', 3324, 295, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,467 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,468 INFO sqlalchemy.engine.base.Engine ('2019-04-14', 3325, 297, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,470 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,471 INFO sqlalchemy.engine.base.Engine ('2019-04-15', 3329, 298, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,472 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,473 INFO sqlalchemy.engine.base.Engine ('2019-04-16', 3331, 299, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,474 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,476 INFO sqlalchemy.engine.base.Engine ('2019-04-17', 3332, 299, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,477 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,478 INFO sqlalchemy.engine.base.Engine ('2019-04-18', 3333, 299, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,479 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,480 INFO sqlalchemy.engine.base.Engine ('2019-04-19', 3336, 299, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,481 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,482 INFO sqlalchemy.engine.base.Engine ('2019-04-20', 3339, 299, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,484 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,485 INFO sqlalchemy.engine.base.Engine ('2019-04-21', 3343, 300, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,487 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,488 INFO sqlalchemy.engine.base.Engine ('2019-04-22', 3349, 302, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,489 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,490 INFO sqlalchemy.engine.base.Engine ('2019-04-23', 3357, 303, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,491 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,493 INFO sqlalchemy.engine.base.Engine ('2019-04-24', 3370, 303, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,494 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,495 INFO sqlalchemy.engine.base.Engine ('2019-04-25', 3388, 304, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,497 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,500 INFO sqlalchemy.engine.base.Engine ('2019-04-26', 3412, 304, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,501 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,505 INFO sqlalchemy.engine.base.Engine ('2019-04-27', 3437, 305, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,508 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,510 INFO sqlalchemy.engine.base.Engine ('2019-04-28', 3439, 305, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,511 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,512 INFO sqlalchemy.engine.base.Engine ('2019-04-29', 3440, 308, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,513 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,514 INFO sqlalchemy.engine.base.Engine ('2019-04-30', 3447, 309, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,515 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,516 INFO sqlalchemy.engine.base.Engine ('2019-05-01', 3466, 310, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,517 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,519 INFO sqlalchemy.engine.base.Engine ('2019-05-02', 3481, 311, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,520 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,520 INFO sqlalchemy.engine.base.Engine ('2019-05-03', 3504, 314, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,521 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,522 INFO sqlalchemy.engine.base.Engine ('2019-05-04', 3522, 317, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,523 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,524 INFO sqlalchemy.engine.base.Engine ('2019-05-05', 3527, 322, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,525 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,526 INFO sqlalchemy.engine.base.Engine ('2019-05-06', 3533, 324, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,527 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,528 INFO sqlalchemy.engine.base.Engine ('2019-05-07', 3543, 327, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,529 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,529 INFO sqlalchemy.engine.base.Engine ('2019-05-08', 3546, 328, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,530 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,531 INFO sqlalchemy.engine.base.Engine ('2019-05-09', 3555, 330, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,532 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,533 INFO sqlalchemy.engine.base.Engine ('2019-05-10', 3566, 332, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,534 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,534 INFO sqlalchemy.engine.base.Engine ('2019-05-11', 3583, 334, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,535 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,536 INFO sqlalchemy.engine.base.Engine ('2019-05-12', 3594, 335, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,537 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,537 INFO sqlalchemy.engine.base.Engine ('2019-05-13', 3614, 338, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,539 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,539 INFO sqlalchemy.engine.base.Engine ('2019-05-14', 3633, 340, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,540 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,541 INFO sqlalchemy.engine.base.Engine ('2019-05-15', 3647, 344, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,542 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,543 INFO sqlalchemy.engine.base.Engine ('2019-05-16', 3648, 349, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,544 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,544 INFO sqlalchemy.engine.base.Engine ('2019-05-17', 3649, 349, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,545 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,546 INFO sqlalchemy.engine.base.Engine ('2019-05-18', 3651, 351, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,547 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,547 INFO sqlalchemy.engine.base.Engine ('2019-05-19', 3654, 351, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,548 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,549 INFO sqlalchemy.engine.base.Engine ('2019-05-20', 3658, 354, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,550 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,551 INFO sqlalchemy.engine.base.Engine ('2019-05-21', 3671, 354, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,552 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,552 INFO sqlalchemy.engine.base.Engine ('2019-05-22', 3675, 359, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,554 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,554 INFO sqlalchemy.engine.base.Engine ('2019-05-23', 3681, 359, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,555 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,556 INFO sqlalchemy.engine.base.Engine ('2019-05-24', 3694, 361, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,557 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,557 INFO sqlalchemy.engine.base.Engine ('2019-05-25', 3699, 361, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,558 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,559 INFO sqlalchemy.engine.base.Engine ('2019-05-26', 3711, 364, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,560 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,561 INFO sqlalchemy.engine.base.Engine ('2019-05-27', 3722, 368, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,562 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,563 INFO sqlalchemy.engine.base.Engine ('2019-05-28', 3734, 373, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,565 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,566 INFO sqlalchemy.engine.base.Engine ('2019-05-29', 3766, 374, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,567 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,568 INFO sqlalchemy.engine.base.Engine ('2019-05-30', 3781, 375, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,569 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,570 INFO sqlalchemy.engine.base.Engine ('2019-05-31', 3784, 375, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,571 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,572 INFO sqlalchemy.engine.base.Engine ('2019-06-01', 3789, 378, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,572 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,573 INFO sqlalchemy.engine.base.Engine ('2019-06-02', 3790, 379, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,574 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,575 INFO sqlalchemy.engine.base.Engine ('2019-06-03', 3793, 380, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,576 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,576 INFO sqlalchemy.engine.base.Engine ('2019-06-04', 3795, 383, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,577 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,578 INFO sqlalchemy.engine.base.Engine ('2019-06-05', 3808, 385, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,579 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,579 INFO sqlalchemy.engine.base.Engine ('2019-06-06', 3830, 386, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,580 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,581 INFO sqlalchemy.engine.base.Engine ('2019-06-07', 3843, 387, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,582 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,583 INFO sqlalchemy.engine.base.Engine ('2019-06-08', 3857, 390, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,584 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,585 INFO sqlalchemy.engine.base.Engine ('2019-06-09', 3870, 394, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,586 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,586 INFO sqlalchemy.engine.base.Engine ('2019-06-10', 3895, 395, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,587 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,588 INFO sqlalchemy.engine.base.Engine ('2019-06-11', 3919, 397, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,589 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,590 INFO sqlalchemy.engine.base.Engine ('2019-06-12', 3942, 399, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,591 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,591 INFO sqlalchemy.engine.base.Engine ('2019-06-13', 3983, 402, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,592 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,594 INFO sqlalchemy.engine.base.Engine ('2019-06-14', 4022, 404, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,595 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,595 INFO sqlalchemy.engine.base.Engine ('2019-06-15', 4053, 409, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,597 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,597 INFO sqlalchemy.engine.base.Engine ('2019-06-16', 4058, 410, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,598 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,599 INFO sqlalchemy.engine.base.Engine ('2019-06-17', 4063, 414, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,600 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,601 INFO sqlalchemy.engine.base.Engine ('2019-06-18', 4064, 417, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,602 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,602 INFO sqlalchemy.engine.base.Engine ('2019-06-19', 4065, 422, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,604 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,605 INFO sqlalchemy.engine.base.Engine ('2019-06-20', 4066, 424, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,606 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,607 INFO sqlalchemy.engine.base.Engine ('2019-06-21', 4069, 425, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,608 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,609 INFO sqlalchemy.engine.base.Engine ('2019-06-22', 4070, 426, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,610 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,610 INFO sqlalchemy.engine.base.Engine ('2019-06-23', 4073, 427, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,611 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,612 INFO sqlalchemy.engine.base.Engine ('2019-06-24', 4084, 427, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,613 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,614 INFO sqlalchemy.engine.base.Engine ('2019-06-25', 4108, 427, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,614 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,615 INFO sqlalchemy.engine.base.Engine ('2019-06-26', 4122, 433, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,616 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,617 INFO sqlalchemy.engine.base.Engine ('2019-06-27', 4132, 436, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,618 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,619 INFO sqlalchemy.engine.base.Engine ('2019-06-28', 4150, 440, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,620 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,620 INFO sqlalchemy.engine.base.Engine ('2019-06-29', 4162, 440, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,621 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,622 INFO sqlalchemy.engine.base.Engine ('2019-06-30', 4164, 446, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,623 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,624 INFO sqlalchemy.engine.base.Engine ('2019-07-01', 4167, 448, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,624 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,625 INFO sqlalchemy.engine.base.Engine ('2019-07-02', 4174, 450, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,626 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,627 INFO sqlalchemy.engine.base.Engine ('2019-07-03', 4179, 455, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,628 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,628 INFO sqlalchemy.engine.base.Engine ('2019-07-04', 4187, 456, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,629 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,630 INFO sqlalchemy.engine.base.Engine ('2019-07-05', 4200, 456, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,631 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,631 INFO sqlalchemy.engine.base.Engine ('2019-07-06', 4210, 458, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,632 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,633 INFO sqlalchemy.engine.base.Engine ('2019-07-07', 4211, 458, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,634 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,635 INFO sqlalchemy.engine.base.Engine ('2019-07-08', 4214, 464, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,636 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,637 INFO sqlalchemy.engine.base.Engine ('2019-07-09', 4219, 464, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,638 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,638 INFO sqlalchemy.engine.base.Engine ('2019-07-10', 4223, 468, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,639 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,639 INFO sqlalchemy.engine.base.Engine ('2019-07-11', 4228, 469, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,640 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,641 INFO sqlalchemy.engine.base.Engine ('2019-07-12', 4236, 469, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,641 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,642 INFO sqlalchemy.engine.base.Engine ('2019-07-13', 4239, 471, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,643 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,644 INFO sqlalchemy.engine.base.Engine ('2019-07-14', 4243, 471, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,645 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,645 INFO sqlalchemy.engine.base.Engine ('2019-07-15', 4250, 473, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,646 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,647 INFO sqlalchemy.engine.base.Engine ('2019-07-16', 4265, 476, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,648 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,649 INFO sqlalchemy.engine.base.Engine ('2019-07-17', 4288, 476, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,650 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,651 INFO sqlalchemy.engine.base.Engine ('2019-07-18', 4313, 483, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,652 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,653 INFO sqlalchemy.engine.base.Engine ('2019-07-19', 4329, 483, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,654 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,654 INFO sqlalchemy.engine.base.Engine ('2019-07-20', 4329, 486, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,655 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,656 INFO sqlalchemy.engine.base.Engine ('2019-07-21', 4329, 487, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,658 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,659 INFO sqlalchemy.engine.base.Engine ('2019-07-22', 4333, 492, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,659 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,660 INFO sqlalchemy.engine.base.Engine ('2019-07-23', 4335, 493, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:46,661 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:46,661 INFO sqlalchemy.engine.base.Engine ('2019-07-24', 4353, 494, '2020-03-11 16:38:13.843948')
# ...
# 2020-03-11 16:49:48,073 INFO sqlalchemy.engine.base.Engine ('2020-01-04', 6011, 768, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,073 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,074 INFO sqlalchemy.engine.base.Engine ('2020-01-05', 6023, 771, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,074 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,075 INFO sqlalchemy.engine.base.Engine ('2020-01-06', 6042, 772, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,076 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,076 INFO sqlalchemy.engine.base.Engine ('2020-01-07', 6060, 776, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,077 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,077 INFO sqlalchemy.engine.base.Engine ('2020-01-08', 6089, 778, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,078 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,078 INFO sqlalchemy.engine.base.Engine ('2020-01-09', 6121, 780, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,079 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,080 INFO sqlalchemy.engine.base.Engine ('2020-01-10', 6174, 781, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,080 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,081 INFO sqlalchemy.engine.base.Engine ('2020-01-11', 6178, 782, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,081 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,082 INFO sqlalchemy.engine.base.Engine ('2020-01-12', 6182, 784, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,083 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,083 INFO sqlalchemy.engine.base.Engine ('2020-01-13', 6188, 784, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,085 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,085 INFO sqlalchemy.engine.base.Engine ('2020-01-14', 6191, 788, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,086 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,087 INFO sqlalchemy.engine.base.Engine ('2020-01-15', 6193, 792, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,088 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,089 INFO sqlalchemy.engine.base.Engine ('2020-01-16', 6196, 793, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,090 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,090 INFO sqlalchemy.engine.base.Engine ('2020-01-17', 6201, 793, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,091 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,092 INFO sqlalchemy.engine.base.Engine ('2020-01-18', 6200, 795, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,093 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,094 INFO sqlalchemy.engine.base.Engine ('2020-01-19', 6204, 797, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,095 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,095 INFO sqlalchemy.engine.base.Engine ('2020-01-20', 6206, 801, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,096 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,097 INFO sqlalchemy.engine.base.Engine ('2020-01-21', 6212, 803, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,098 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,098 INFO sqlalchemy.engine.base.Engine ('2020-01-22', 6213, 806, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,099 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,100 INFO sqlalchemy.engine.base.Engine ('2020-01-23', 6215, 808, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,101 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,101 INFO sqlalchemy.engine.base.Engine ('2020-01-24', 6219, 808, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,103 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,104 INFO sqlalchemy.engine.base.Engine ('2020-01-25', 6222, 811, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,105 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,105 INFO sqlalchemy.engine.base.Engine ('2020-01-26', 6223, 811, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,106 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,107 INFO sqlalchemy.engine.base.Engine ('2020-01-27', 6224, 811, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,108 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,109 INFO sqlalchemy.engine.base.Engine ('2020-01-28', 6229, 812, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,110 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,111 INFO sqlalchemy.engine.base.Engine ('2020-01-29', 6248, 812, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,111 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,112 INFO sqlalchemy.engine.base.Engine ('2020-01-30', 6281, 813, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,113 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,113 INFO sqlalchemy.engine.base.Engine ('2020-01-31', 6286, 816, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,114 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,115 INFO sqlalchemy.engine.base.Engine ('2020-02-01', 6291, 820, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,115 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,116 INFO sqlalchemy.engine.base.Engine ('2020-02-02', 6294, 820, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,116 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,117 INFO sqlalchemy.engine.base.Engine ('2020-02-03', 6299, 820, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,119 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,120 INFO sqlalchemy.engine.base.Engine ('2020-02-04', 6310, 821, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,121 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,122 INFO sqlalchemy.engine.base.Engine ('2020-02-05', 6319, 824, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,123 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,124 INFO sqlalchemy.engine.base.Engine ('2020-02-06', 6337, 827, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,125 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,126 INFO sqlalchemy.engine.base.Engine ('2020-02-07', 6352, 829, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,127 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,127 INFO sqlalchemy.engine.base.Engine ('2020-02-08', 6353, 833, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,128 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,129 INFO sqlalchemy.engine.base.Engine ('2020-02-09', 6356, 834, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,130 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,131 INFO sqlalchemy.engine.base.Engine ('2020-02-10', 6359, 836, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,132 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,132 INFO sqlalchemy.engine.base.Engine ('2020-02-11', 6361, 843, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,133 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,134 INFO sqlalchemy.engine.base.Engine ('2020-02-12', 6366, 845, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,136 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,136 INFO sqlalchemy.engine.base.Engine ('2020-02-13', 6370, 848, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,137 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,138 INFO sqlalchemy.engine.base.Engine ('2020-02-14', 6387, 852, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,139 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,141 INFO sqlalchemy.engine.base.Engine ('2020-02-15', 6399, 854, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,142 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,143 INFO sqlalchemy.engine.base.Engine ('2020-02-16', 6399, 854, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,144 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,145 INFO sqlalchemy.engine.base.Engine ('2020-02-17', 6407, 857, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,145 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,146 INFO sqlalchemy.engine.base.Engine ('2020-02-18', 6411, 860, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,147 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,148 INFO sqlalchemy.engine.base.Engine ('2020-02-19', 6412, 861, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,149 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,149 INFO sqlalchemy.engine.base.Engine ('2020-02-20', 6413, 861, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,151 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,152 INFO sqlalchemy.engine.base.Engine ('2020-02-21', 6428, 862, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,153 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,154 INFO sqlalchemy.engine.base.Engine ('2020-02-22', 6436, 862, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,155 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,156 INFO sqlalchemy.engine.base.Engine ('2020-02-23', 6439, 867, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,157 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,158 INFO sqlalchemy.engine.base.Engine ('2020-02-24', 6442, 868, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,159 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,159 INFO sqlalchemy.engine.base.Engine ('2020-02-25', 6455, 869, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,160 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,161 INFO sqlalchemy.engine.base.Engine ('2020-02-26', 6460, 871, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,162 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,162 INFO sqlalchemy.engine.base.Engine ('2020-02-27', 6470, 872, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,163 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,164 INFO sqlalchemy.engine.base.Engine ('2020-02-28', 6482, 873, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,165 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,166 INFO sqlalchemy.engine.base.Engine ('2020-02-29', 6495, 876, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,167 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,168 INFO sqlalchemy.engine.base.Engine ('2020-03-01', 6500, 876, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,170 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,170 INFO sqlalchemy.engine.base.Engine ('2020-03-02', 6504, 878, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,171 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,172 INFO sqlalchemy.engine.base.Engine ('2020-03-03', 6510, 885, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,174 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,174 INFO sqlalchemy.engine.base.Engine ('2020-03-03', 6515, 890, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,176 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,176 INFO sqlalchemy.engine.base.Engine ('2020-03-03', 6515, 890, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,177 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,178 INFO sqlalchemy.engine.base.Engine ('2020-03-03', 6515, 890, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,179 INFO sqlalchemy.engine.base.Engine INSERT INTO data (date, subscribers, reviews, timestamp) VALUES (?, ?, ?, ?)
# 2020-03-11 16:49:48,179 INFO sqlalchemy.engine.base.Engine ('2020-03-04', 6522, 890, '2020-03-11 16:38:13.843948')
# 2020-03-11 16:49:48,192 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
def read_data():
    from assets import models
    df = pd.read_csv('assets/data.csv')
    for index,_df in df.iterrows():
        date = datetime.datetime.strptime(_df['date'],'%Y/%m/%d').date()
        row = models.Data(date=date, subscribers=_df['subscribers'], reviews=_df['reviews'])
        db_session.add(row)
    db_session.commit()
